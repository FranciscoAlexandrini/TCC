# %%
import pandas as pd
import yfinance as yf
from datetime import date
import pandas_ta as ta

# %%
def analyze_stock(stock, dados, start, end, window_size):
    # Baixa os dados históricos da ação do Yahoo Finance
    data = yf.download(stock, start=start, end=end)
    
    # Verifica se os dados foram baixados corretamente
    if not data.empty:
        # Reseta o índice para tratar a data como uma coluna
        data.reset_index(inplace=True)
        # Converte a coluna de data para o formato de string 'AAAA-MM-DD'
        dados['Date'] = data['Date'].dt.strftime('%Y-%m-%d')
        # Calcula a variação percentual diária do preço de fechamento ajustado
        dados['Var Percentual'] = data['Adj Close'].pct_change() * 100
        # Calcula a média móvel e o desvio padrão das variações percentuais
        media_rolling = dados['Var Percentual'].rolling(window=window_size).mean()
        desvio_padrao_rolling = dados['Var Percentual'].rolling(window=window_size).std()
        dados['Variancia'] =  dados['Var Percentual'].rolling(window=window_size).var()
        # Calculando a média da variância dos retornos usando a mesma janela
        dados['Media Variancia'] = dados['Variancia'].rolling(window=window_size).mean()
        if isinstance(data, pd.Series):
            data = data.to_frame()
        # Calculando o RSI
        rsi = data.ta.rsi(close='Adj Close', length=14)
        dados['rsi'] = rsi
        dados['Stock'] = stock
        print(type(dados['Date']))
        temp_datas = pd.to_datetime(dados['Date'])
        dados['AnoMes'] = temp_datas.dt.to_period('M')
        #print("Dataframe\n {}".format(dados))
        #dsv_sup1 = media_rolling + (desvio_padrao_rolling * 1.5)
        #dsv_sup2 = media_rolling + (desvio_padrao_rolling * 3)
        #dsv_inf1 = media_rolling - (desvio_padrao_rolling * 1.5)
        #dsv_inf2 = media_rolling - (desvio_padrao_rolling * 3)
        dados_filt = dados [(dados['rsi']>= 80) & (dados['Variancia'] < dados['Media Variancia']) & (dados['Var Percentual']< 4)] 
        dados_unique = dados_filt.drop_duplicates(subset='AnoMes', keep='first')
        dados_unique = dados_unique.drop('AnoMes',axis=1)
        print("Dados únicos")
        print(dados_unique)
        return dados_unique
    else:
        return dados

# %%
# Definição de parâmetros iniciais
stocksymbols = ["PETR4.SA", 'VALE3.SA', 'ITUB4.SA', 'BBAS3.SA', 'BBDC3.SA']
startdate = date(2002, 1, 1)
end_date = date(2023, 12, 31)
window_size = 100

# Processamento de múltiplas ações
all_results = pd.DataFrame()
dados = pd.DataFrame(columns=('Date','AnoMes','Var Percentual','rsi','Variancia','Media Variancia','Stock'))
for stock in stocksymbols:
    stock_results = analyze_stock(stock, dados, startdate, end_date, window_size)
    if not stock_results.empty:
        # Combina os resultados de todas as ações em um único DataFrame
        all_results = pd.concat([all_results, stock_results], ignore_index=True)

# Salva os resultados finais em um arquivo JSON
if not all_results.empty:
    all_results.to_json('filtered_vendacoberta_results.json', orient='records')
    print(all_results)
else:
    print("Nenhum dado foi encontrado para as condições especificadas.")
# Out:
# [*********************100%***********************]  1 of 1 completed
# <class 'pandas.core.series.Series'>
# Dados únicos
#             Date  Var Percentual        rsi  Variancia  Media Variancia  \
# 712   2004-09-23        2.837153  81.101000   3.277354         4.746867
# 718   2004-10-01        0.170518  84.565755   2.306182         4.577960
# 961   2005-09-19        2.530859  82.595272   2.423114         2.936716
# 1288  2006-12-27        2.305522  81.136591   2.410940         3.310577
# 1290  2007-01-02        1.965523  84.692541   2.436940         3.288886
# 1627  2008-05-19        3.842139  81.274123   7.882135        10.578871
# 3716  2016-10-21        1.183763  80.122972   8.391731        15.635679
# 4032  2018-01-22        1.150060  80.036968   3.100011         3.967187
# 5366  2023-06-12        1.750327  81.942058   4.836659         7.173687
#
#          Stock
# 712   PETR4.SA
# 718   PETR4.SA
# 961   PETR4.SA
# 1288  PETR4.SA
# 1290  PETR4.SA
# 1627  PETR4.SA
# 3716  PETR4.SA
# 4032  PETR4.SA
# 5366  PETR4.SA
# [*********************100%***********************]  1 of 1 completed
# <class 'pandas.core.series.Series'>
# Dados únicos
#             Date  Var Percentual        rsi  Variancia  Media Variancia  \
# 411   2003-07-30        2.030493  80.764232   2.267005         2.540892
# 413   2003-08-01        0.874604  83.887537   2.275971         2.522994
# 965   2005-09-23        2.468527  80.743476   3.280286         5.015969
# 4016  2017-12-28        1.003505  80.149870   3.128788         3.801155
# 4018  2018-01-02        3.626436  84.605714   3.160125         3.770114
# 4107  2018-05-11        2.392998  80.601849   3.301036         3.357765
# 4736  2020-11-25        0.935843  80.519958   4.489629         9.145075
# 4747  2020-12-10        2.781148  81.071105   4.281300         6.999859
# 4761  2021-01-05        1.683797  83.548674   3.924650         4.725570
#
#          Stock
# 411   VALE3.SA
# 413   VALE3.SA
# 965   VALE3.SA
# 4016  VALE3.SA
# 4018  VALE3.SA
# 4107  VALE3.SA
# 4736  VALE3.SA
# 4747  VALE3.SA
# 4761  VALE3.SA
# [*********************100%***********************]  1 of 1 completed
# <class 'pandas.core.series.Series'>
# Dados únicos
#             Date  Var Percentual        rsi  Variancia  Media Variancia  \
# 318   2003-03-21        3.888928  81.435037   4.302039         8.761737
# 4032  2018-01-22        2.486184  80.741587   1.685606         1.767507
# 4864  2021-06-07        2.354432  80.416991   4.670476         5.059264
# 5161  2022-08-12        1.211194  80.342589   1.938182         2.562020
#
#          Stock
# 318   ITUB4.SA
# 4032  ITUB4.SA
# 4864  ITUB4.SA
# 5161  ITUB4.SA
# [*********************100%***********************]  1 of 1 completed
# <class 'pandas.core.series.Series'>
# Dados únicos
#             Date  Var Percentual        rsi  Variancia  Media Variancia  \
# 492   2003-11-20        3.464275  81.402114   4.543438         5.902821
# 499   2003-12-01        1.632652  87.606373   4.693760         5.778197
# 965   2005-09-23        1.872785  81.861635   5.164862         5.184060
# 1960  2009-09-16        1.421640  80.523509   5.189452         8.378264
# 2773  2013-01-02        0.781249  80.416415   4.272671         5.448693
# 2982  2013-10-31        1.674662  82.257319   3.468173         3.530020
# 2983  2013-11-01       -0.168059  81.190735   3.441785         3.538101
# 3156  2014-07-22        0.692537  80.687604   4.914843         5.456002
# 3183  2014-08-28        1.094284  82.471949   4.128836         5.420936
# 3185  2014-09-01        0.653415  87.088051   4.381787         5.396079
# 3946  2017-09-21        2.186411  80.081105   7.756933         8.096126
# 4035  2018-01-25        0.000000  82.035348   3.861775         4.213160
# 4040  2018-02-01        0.277220  83.154249   3.867433         4.006617
# 4287  2019-02-05        2.919048  80.661566   6.587391         8.634215
# 4862  2021-06-02        3.590387  83.862225   5.284915         5.722242
# 5157  2022-08-08        3.148975  80.704671   2.506400         3.123518
# 5366  2023-06-12        3.623799  85.930336   2.946627         4.524975
#
#          Stock
# 492   BBAS3.SA
# 499   BBAS3.SA
# 965   BBAS3.SA
# 1960  BBAS3.SA
# 2773  BBAS3.SA
# 2982  BBAS3.SA
# 2983  BBAS3.SA
# 3156  BBAS3.SA
# 3183  BBAS3.SA
# 3185  BBAS3.SA
# 3946  BBAS3.SA
# 4035  BBAS3.SA
# 4040  BBAS3.SA
# 4287  BBAS3.SA
# 4862  BBAS3.SA
# 5157  BBAS3.SA
# 5366  BBAS3.SA
# [*********************100%***********************]  1 of 1 completed
# <class 'pandas.core.series.Series'>
# Dados únicos
#             Date  Var Percentual        rsi  Variancia  Media Variancia  \
# 726   2004-10-13        0.383176  80.047204   2.243522         3.916206
# 763   2004-12-06        3.323833  82.460970   2.707427         3.019909
# 1052  2006-01-30        3.072553  82.253683   4.060728         4.651951
# 1054  2006-02-01       -0.550499  81.241965   3.977845         4.634846
# 1962  2009-09-18        1.953937  82.292181   3.565917         5.139396
# 4029  2018-01-17        3.062729  80.879120   1.963300         2.615325
#
#          Stock
# 726   BBDC3.SA
# 763   BBDC3.SA
# 1052  BBDC3.SA
# 1054  BBDC3.SA
# 1962  BBDC3.SA
# 4029  BBDC3.SA
#           Date  Var Percentual        rsi  Variancia  Media Variancia  \
# 0   2004-09-23        2.837153  81.101000   3.277354         4.746867
# 1   2004-10-01        0.170518  84.565755   2.306182         4.577960
# 2   2005-09-19        2.530859  82.595272   2.423114         2.936716
# 3   2006-12-27        2.305522  81.136591   2.410940         3.310577
# 4   2007-01-02        1.965523  84.692541   2.436940         3.288886
# 5   2008-05-19        3.842139  81.274123   7.882135        10.578871
# 6   2016-10-21        1.183763  80.122972   8.391731        15.635679
# 7   2018-01-22        1.150060  80.036968   3.100011         3.967187
# 8   2023-06-12        1.750327  81.942058   4.836659         7.173687
# 9   2003-07-30        2.030493  80.764232   2.267005         2.540892
# 10  2003-08-01        0.874604  83.887537   2.275971         2.522994
# 11  2005-09-23        2.468527  80.743476   3.280286         5.015969
# 12  2017-12-28        1.003505  80.149870   3.128788         3.801155
# 13  2018-01-02        3.626436  84.605714   3.160125         3.770114
# 14  2018-05-11        2.392998  80.601849   3.301036         3.357765
# 15  2020-11-25        0.935843  80.519958   4.489629         9.145075
# 16  2020-12-10        2.781148  81.071105   4.281300         6.999859
# 17  2021-01-05        1.683797  83.548674   3.924650         4.725570
# 18  2003-03-21        3.888928  81.435037   4.302039         8.761737
# 19  2018-01-22        2.486184  80.741587   1.685606         1.767507
# 20  2021-06-07        2.354432  80.416991   4.670476         5.059264
# 21  2022-08-12        1.211194  80.342589   1.938182         2.562020
# 22  2003-11-20        3.464275  81.402114   4.543438         5.902821
# 23  2003-12-01        1.632652  87.606373   4.693760         5.778197
# 24  2005-09-23        1.872785  81.861635   5.164862         5.184060
# 25  2009-09-16        1.421640  80.523509   5.189452         8.378264
# 26  2013-01-02        0.781249  80.416415   4.272671         5.448693
# 27  2013-10-31        1.674662  82.257319   3.468173         3.530020
# 28  2013-11-01       -0.168059  81.190735   3.441785         3.538101
# 29  2014-07-22        0.692537  80.687604   4.914843         5.456002
# 30  2014-08-28        1.094284  82.471949   4.128836         5.420936
# 31  2014-09-01        0.653415  87.088051   4.381787         5.396079
# 32  2017-09-21        2.186411  80.081105   7.756933         8.096126
# 33  2018-01-25        0.000000  82.035348   3.861775         4.213160
# 34  2018-02-01        0.277220  83.154249   3.867433         4.006617
# 35  2019-02-05        2.919048  80.661566   6.587391         8.634215
# 36  2021-06-02        3.590387  83.862225   5.284915         5.722242
# 37  2022-08-08        3.148975  80.704671   2.506400         3.123518
# 38  2023-06-12        3.623799  85.930336   2.946627         4.524975
# 39  2004-10-13        0.383176  80.047204   2.243522         3.916206
# 40  2004-12-06        3.323833  82.460970   2.707427         3.019909
# 41  2006-01-30        3.072553  82.253683   4.060728         4.651951
# 42  2006-02-01       -0.550499  81.241965   3.977845         4.634846
# 43  2009-09-18        1.953937  82.292181   3.565917         5.139396
# 44  2018-01-17        3.062729  80.879120   1.963300         2.615325
#
#        Stock
# 0   PETR4.SA
# 1   PETR4.SA
# 2   PETR4.SA
# 3   PETR4.SA
# 4   PETR4.SA
# 5   PETR4.SA
# 6   PETR4.SA
# 7   PETR4.SA
# 8   PETR4.SA
# 9   VALE3.SA
# 10  VALE3.SA
# 11  VALE3.SA
# 12  VALE3.SA
# 13  VALE3.SA
# 14  VALE3.SA
# 15  VALE3.SA
# 16  VALE3.SA
# 17  VALE3.SA
# 18  ITUB4.SA
# 19  ITUB4.SA
# 20  ITUB4.SA
# 21  ITUB4.SA
# 22  BBAS3.SA
# 23  BBAS3.SA
# 24  BBAS3.SA
# 25  BBAS3.SA
# 26  BBAS3.SA
# 27  BBAS3.SA
# 28  BBAS3.SA
# 29  BBAS3.SA
# 30  BBAS3.SA
# 31  BBAS3.SA
# 32  BBAS3.SA
# 33  BBAS3.SA
# 34  BBAS3.SA
# 35  BBAS3.SA
# 36  BBAS3.SA
# 37  BBAS3.SA
# 38  BBAS3.SA
# 39  BBDC3.SA
# 40  BBDC3.SA
# 41  BBDC3.SA
# 42  BBDC3.SA
# 43  BBDC3.SA
# 44  BBDC3.SA
