# %%
import pandas as pd
import yfinance as yf
from datetime import date
import pandas_ta as ta

# %%
def analyze_stock(stock, dados, start, end, window_size):
    # Baixa os dados históricos da ação do Yahoo Finance
    data = yf.download(stock, start=start, end=end)
    
    # Verifica se os dados foram baixados corretamente
    if not data.empty:
        # Reseta o índice para tratar a data como uma coluna
        data.reset_index(inplace=True)
        # Converte a coluna de data para o formato de string 'AAAA-MM-DD'
        dados['Date'] = data['Date'].dt.strftime('%Y-%m-%d')
        # Calcula a variação percentual diária do preço de fechamento ajustado
        dados['Var Percentual'] = data['Adj Close'].pct_change() * 100
        # Calcula a média móvel e o desvio padrão das variações percentuais
        media_rolling = dados['Var Percentual'].rolling(window=window_size).mean()
        desvio_padrao_rolling = dados['Var Percentual'].rolling(window=window_size).std()
        dados['Variancia'] =  dados['Var Percentual'].rolling(window=window_size).var()
        # Calculando a média da variância dos retornos usando a mesma janela
        dados['Media Variancia'] = dados['Variancia'].rolling(window=window_size).mean()
        if isinstance(data, pd.Series):
            data = data.to_frame()
        # Calculando o RSI
        rsi = data.ta.rsi(close='Adj Close', length=14)
        dados['rsi'] = rsi
        dados['Stock'] = stock
        print(type(dados['Date']))
        temp_datas = pd.to_datetime(dados['Date'])
        dados['AnoMes'] = temp_datas.dt.to_period('M')
        print("Dataframe\n {}".format(dados))
        dsv_sup1 = media_rolling + (desvio_padrao_rolling * 1.5)
        dsv_sup2 = media_rolling + (desvio_padrao_rolling * 3)
        dsv_inf1 = media_rolling - (desvio_padrao_rolling * 1.5)
        dsv_inf2 = media_rolling - (desvio_padrao_rolling * 3)
        diferenca = dsv_sup1 - dsv_inf1
        dados['DiferencaDesvios'] = diferenca
        media_diferenca = diferenca.rolling(window=252).mean()
        dados['MediaDiferencaDesvios'] = media_diferenca
        print(media_diferenca)
        dados_filt = dados [(dados['rsi']>= 48)& (dados['rsi']<=52) & (dados['Variancia'] < dados['Media Variancia']) & (dados['Var Percentual']< 4) & (dados['DiferencaDesvios']<dados['MediaDiferencaDesvios'])] 
        dados_unique = dados_filt.drop_duplicates(subset='AnoMes', keep='first')
        dados_unique = dados_unique.drop('AnoMes',axis=1)
        print("Dados únicos")
        print(dados_unique)
        return dados_unique
    else:
        return dados

# %%
# Definição de parâmetros iniciais
stocksymbols = ["PETR4.SA", 'VALE3.SA', 'ITUB4.SA', 'BBAS3.SA', 'BBDC3.SA']
startdate = date(2002, 1, 1)
end_date = date(2023, 12, 31)
window_size = 100

# Processamento de múltiplas ações
all_results = pd.DataFrame()
dados = pd.DataFrame(columns=('Date','AnoMes','Var Percentual','DiferencaDesvios','MediaDiferencaDesvios','rsi','Variancia','Media Variancia','Stock'))
for stock in stocksymbols:
    stock_results = analyze_stock(stock, dados, startdate, end_date, window_size)
    if not stock_results.empty:
        # Combina os resultados de todas as ações em um único DataFrame
        all_results = pd.concat([all_results, stock_results], ignore_index=True)

# Salva os resultados finais em um arquivo JSON
if not all_results.empty:
    all_results.to_json('filtered_straddle_results.json', orient='records')
    print(all_results)
else:
    print("Nenhum dado foi encontrado para as condições especificadas.")
# Out:
# [*********************100%***********************]  1 of 1 completed
# <class 'pandas.core.series.Series'>
# Dataframe
#              Date   AnoMes  Var Percentual DiferencaDesvios  \
# 0     2002-01-01  2002-01             NaN              NaN
# 1     2002-01-02  2002-01        0.195504              NaN
# 2     2002-01-03  2002-01        0.682936              NaN
# 3     2002-01-04  2002-01       -0.620177              NaN
# 4     2002-01-07  2002-01        2.184114              NaN
# ...          ...      ...             ...              ...
# 5500  2023-12-21  2023-12        0.027479              NaN
# 5501  2023-12-22  2023-12        0.961816              NaN
# 5502  2023-12-26  2023-12        1.605881              NaN
# 5503  2023-12-27  2023-12        0.080360              NaN
# 5504  2023-12-28  2023-12       -0.321204              NaN
#
#      MediaDiferencaDesvios        rsi  Variancia  Media Variancia     Stock
# 0                      NaN        NaN        NaN              NaN  PETR4.SA
# 1                      NaN        NaN        NaN              NaN  PETR4.SA
# 2                      NaN        NaN        NaN              NaN  PETR4.SA
# 3                      NaN        NaN        NaN              NaN  PETR4.SA
# 4                      NaN        NaN        NaN              NaN  PETR4.SA
# ...                    ...        ...        ...              ...       ...
# 5500                   NaN  63.016514   3.241184         3.890049  PETR4.SA
# 5501                   NaN  65.364252   3.062534         3.875836  PETR4.SA
# 5502                   NaN  68.943246   3.043511         3.861087  PETR4.SA
# 5503                   NaN  69.117979   3.041229         3.846345  PETR4.SA
# 5504                   NaN  67.482363   3.034985         3.831759  PETR4.SA
#
# [5505 rows x 9 columns]
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
#           ...
# 5500    7.041440
# 5501    7.025254
# 5502    7.009086
# 5503    6.993498
# 5504    6.977490
# Name: Var Percentual, Length: 5505, dtype: float64
# Dados únicos
#             Date  Var Percentual  DiferencaDesvios  MediaDiferencaDesvios  \
# 391   2003-07-02        1.681636          5.194070               7.197635
# 415   2003-08-05        2.238791          4.748832               7.061025
# 451   2003-09-24        0.921791          4.847585               6.693434
# 474   2003-10-27        0.550761          4.814651               6.331659
# 484   2003-11-10       -1.041335          4.683264               6.175630
# ...          ...             ...               ...                    ...
# 5387  2023-07-11       -1.353641          6.454571               7.822846
# 5405  2023-08-04       -2.975413          6.350088               7.791145
# 5463  2023-10-27       -0.728296          6.178775               7.501933
# 5466  2023-11-01        1.093826          5.984898               7.476003
# 5487  2023-12-04       -2.130638          5.537637               7.221406
#
#             rsi  Variancia  Media Variancia     Stock
# 391   49.926729   2.997596         4.409467  PETR4.SA
# 415   48.910153   2.505711         3.726799  PETR4.SA
# 451   50.194495   2.611008         3.081253  PETR4.SA
# 474   49.589733   2.575652         2.722941  PETR4.SA
# 484   51.910799   2.436995         2.646351  PETR4.SA
# ...         ...        ...              ...       ...
# 5387  51.284783   4.629054         6.220555  PETR4.SA
# 5405  51.439776   4.480402         5.453142  PETR4.SA
# 5463  51.274568   4.241918         4.270104  PETR4.SA
# 5466  49.478077   3.979889         4.248970  PETR4.SA
# 5487  51.385285   3.407269         4.019207  PETR4.SA
#
# [86 rows x 8 columns]
# [*********************100%***********************]  1 of 1 completed
# <class 'pandas.core.series.Series'>
# Dataframe
#              Date   AnoMes  Var Percentual  DiferencaDesvios  \
# 0     2002-01-01  2002-01             NaN               NaN
# 1     2002-01-02  2002-01       -1.923093               NaN
# 2     2002-01-03  2002-01        1.568626               NaN
# 3     2002-01-04  2002-01        2.123546               NaN
# 4     2002-01-07  2002-01        0.000000               NaN
# ...          ...      ...             ...               ...
# 5500  2023-12-21  2023-12        3.329310          5.400987
# 5501  2023-12-22  2023-12       -0.753543          5.250029
# 5502  2023-12-26  2023-12        0.353458          5.233698
# 5503  2023-12-27  2023-12        0.965298          5.231736
# 5504  2023-12-28  2023-12       -0.258408          5.226362
#
#       MediaDiferencaDesvios        rsi  Variancia  Media Variancia     Stock
# 0                       NaN        NaN        NaN              NaN  VALE3.SA
# 1                       NaN        NaN        NaN              NaN  VALE3.SA
# 2                       NaN        NaN        NaN              NaN  VALE3.SA
# 3                       NaN        NaN        NaN              NaN  VALE3.SA
# 4                       NaN        NaN        NaN              NaN  VALE3.SA
# ...                     ...        ...        ...              ...       ...
# 5500               7.041440  71.442107   2.474032         3.088815  VALE3.SA
# 5501               7.025254  67.104844   2.438196         3.078025  VALE3.SA
# 5502               7.009086  68.076476   2.414372         3.066970  VALE3.SA
# 5503               6.993498  70.636360   2.387520         3.055566  VALE3.SA
# 5504               6.977490  69.025270   2.387631         3.044098  VALE3.SA
#
# [5505 rows x 9 columns]
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
#           ...
# 5500    5.702369
# 5501    5.690060
# 5502    5.677658
# 5503    5.665197
# 5504    5.652903
# Name: Var Percentual, Length: 5505, dtype: float64
# Dados únicos
#             Date  Var Percentual  DiferencaDesvios  MediaDiferencaDesvios  \
# 371   2003-06-04       -0.114572          4.751873               5.701536
# 453   2003-09-26       -1.032788          4.568542               5.353735
# 734   2004-10-25       -0.324701          6.747161               6.874586
# 739   2004-11-01        0.000000          6.723611               6.902437
# 763   2004-12-06       -1.361591          6.290389               6.979013
# ...          ...             ...               ...                    ...
# 5364  2023-06-07        1.582848          5.448120               6.781533
# 5387  2023-07-11        3.288868          5.572041               6.609263
# 5440  2023-09-25       -2.058826          5.342859               6.297044
# 5445  2023-10-02       -0.873049          5.227225               6.259102
# 5489  2023-12-06       -0.658880          4.994498               5.828500
#
#             rsi  Variancia  Media Variancia     Stock
# 371   51.951529   2.508922         2.923332  VALE3.SA
# 453   51.959294   2.319064         2.437398  VALE3.SA
# 734   51.140699   5.058242         5.710752  VALE3.SA
# 739   49.617651   5.022993         5.631692  VALE3.SA
# 763   50.643582   4.396555         5.225612  VALE3.SA
# ...         ...        ...              ...       ...
# 5364  50.446147   3.298002         3.944477  VALE3.SA
# 5387  49.996569   3.449738         3.475128  VALE3.SA
# 5440  48.610142   3.171794         3.305974  VALE3.SA
# 5445  50.765882   3.035987         3.318124  VALE3.SA
# 5489  51.997898   2.771668         3.174034  VALE3.SA
#
# [86 rows x 8 columns]
# [*********************100%***********************]  1 of 1 completed
# <class 'pandas.core.series.Series'>
# Dataframe
#              Date   AnoMes  Var Percentual  DiferencaDesvios  \
# 0     2002-01-01  2002-01             NaN               NaN
# 1     2002-01-02  2002-01        4.551435               NaN
# 2     2002-01-03  2002-01       -1.092355               NaN
# 3     2002-01-04  2002-01       -1.643026               NaN
# 4     2002-01-07  2002-01       -1.111660               NaN
# ...          ...      ...             ...               ...
# 5500  2023-12-21  2023-12        0.675473          4.718717
# 5501  2023-12-22  2023-12        1.585843          4.684417
# 5502  2023-12-26  2023-12        1.020728          4.661475
# 5503  2023-12-27  2023-12        0.683491          4.635481
# 5504  2023-12-28  2023-12        0.265642          4.635588
#
#       MediaDiferencaDesvios        rsi  Variancia  Media Variancia     Stock
# 0                       NaN        NaN        NaN              NaN  ITUB4.SA
# 1                       NaN        NaN        NaN              NaN  ITUB4.SA
# 2                       NaN        NaN        NaN              NaN  ITUB4.SA
# 3                       NaN        NaN        NaN              NaN  ITUB4.SA
# 4                       NaN        NaN        NaN              NaN  ITUB4.SA
# ...                     ...        ...        ...              ...       ...
# 5500               5.702369  71.377638   1.449312         1.645950  ITUB4.SA
# 5501               5.690060  75.174506   1.469155         1.640642  ITUB4.SA
# 5502               5.677658  77.295324   1.476092         1.635518  ITUB4.SA
# 5503               5.665197  78.625529   1.475964         1.630809  ITUB4.SA
# 5504               5.652903  79.140537   1.466496         1.626585  ITUB4.SA
#
# [5505 rows x 9 columns]
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
#           ...
# 5500    4.840194
# 5501    4.832923
# 5502    4.825693
# 5503    4.818468
# 5504    4.811141
# Name: Var Percentual, Length: 5505, dtype: float64
# Dados únicos
#             Date  Var Percentual  DiferencaDesvios  MediaDiferencaDesvios  \
# 360   2003-05-20       -2.030397          5.918889               8.129294
# 369   2003-06-02       -0.499976          6.083296               8.135821
# 399   2003-07-14        2.863251          5.536306               8.021959
# 416   2003-08-06       -1.454049          5.384763               7.832297
# 444   2003-09-15       -2.608635          5.594012               7.390896
# ...          ...             ...               ...                    ...
# 5388  2023-07-12       -0.597748          4.353031               5.148690
# 5404  2023-08-03       -0.768716          4.123057               5.140335
# 5425  2023-09-01        0.866944          3.869620               5.123100
# 5447  2023-10-04        2.293218          3.756005               5.084927
# 5466  2023-11-01        1.409018          3.745470               5.018764
#
#             rsi  Variancia  Media Variancia     Stock
# 360   48.507660   3.892583         5.561045  ITUB4.SA
# 369   51.248428   4.111832         5.193996  ITUB4.SA
# 399   50.617834   3.405632         4.121211  ITUB4.SA
# 416   51.673534   3.221741         3.745794  ITUB4.SA
# 444   50.800982   3.476997         3.511280  ITUB4.SA
# ...         ...        ...              ...       ...
# 5388  51.052282   2.105431         3.461432  ITUB4.SA
# 5404  49.808456   1.888844         3.134267  ITUB4.SA
# 5425  50.332209   1.663773         2.693626  ITUB4.SA
# 5447  51.788771   1.567508         2.281199  ITUB4.SA
# 5466  49.863757   1.558727         1.963386  ITUB4.SA
#
# [96 rows x 8 columns]
# [*********************100%***********************]  1 of 1 completed
# <class 'pandas.core.series.Series'>
# Dataframe
#              Date   AnoMes  Var Percentual  DiferencaDesvios  \
# 0     2002-01-01  2002-01             NaN               NaN
# 1     2002-01-02  2002-01        1.794164               NaN
# 2     2002-01-03  2002-01        1.576960               NaN
# 3     2002-01-04  2002-01       -2.283091               NaN
# 4     2002-01-07  2002-01       -2.242950               NaN
# ...          ...      ...             ...               ...
# 5500  2023-12-21  2023-12        0.147581          3.611621
# 5501  2023-12-22  2023-12        0.276281          3.636261
# 5502  2023-12-26  2023-12        0.918447          3.644836
# 5503  2023-12-27  2023-12       -0.145606          3.644677
# 5504  2023-12-28  2023-12        0.966092          3.632968
#
#       MediaDiferencaDesvios        rsi  Variancia  Media Variancia     Stock
# 0                       NaN        NaN        NaN              NaN  BBAS3.SA
# 1                       NaN        NaN        NaN              NaN  BBAS3.SA
# 2                       NaN        NaN        NaN              NaN  BBAS3.SA
# 3                       NaN        NaN        NaN              NaN  BBAS3.SA
# 4                       NaN        NaN        NaN              NaN  BBAS3.SA
# ...                     ...        ...        ...              ...       ...
# 5500               4.840194  63.632613   1.779288         2.056368  BBAS3.SA
# 5501               4.832923  64.466213   1.749244         2.049665  BBAS3.SA
# 5502               4.825693  67.167871   1.716955         2.042300  BBAS3.SA
# 5503               4.818468  66.299356   1.717724         2.035536  BBAS3.SA
# 5504               4.811141  69.145918   1.723407         2.029304  BBAS3.SA
#
# [5505 rows x 9 columns]
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
#           ...
# 5500    5.408381
# 5501    5.394140
# 5502    5.379812
# 5503    5.365481
# 5504    5.351055
# Name: Var Percentual, Length: 5505, dtype: float64
# Dados únicos
#             Date  Var Percentual  DiferencaDesvios  MediaDiferencaDesvios  \
# 415   2003-08-05        0.575589          7.413053               9.273143
# 451   2003-09-24       -2.102145          7.292041               8.706043
# 456   2003-10-01        2.812489          7.313230               8.614285
# 518   2003-12-26       -1.467511          6.335297               7.461166
# 523   2004-01-02       -1.249982          6.073209               7.391796
# ...          ...             ...               ...                    ...
# 5387  2023-07-11       -1.427401          4.956588               6.131401
# 5403  2023-08-02        0.443426          4.641860               6.106423
# 5427  2023-09-05       -0.359651          4.285353               6.062836
# 5447  2023-10-04        0.753495          4.304651               5.975003
# 5466  2023-11-01        0.103410          3.963620               5.835900
#
#             rsi  Variancia  Media Variancia     Stock
# 415   48.293777   6.105929         6.154615  BBAS3.SA
# 451   48.585579   5.908208         6.415680  BBAS3.SA
# 456   51.743935   5.942592         6.420558  BBAS3.SA
# 518   50.514333   4.459555         5.471496  BBAS3.SA
# 523   51.848295   4.098208         5.357542  BBAS3.SA
# ...         ...        ...              ...       ...
# 5387  49.618250   2.729752         3.755466  BBAS3.SA
# 5403  48.002073   2.394096         3.234397  BBAS3.SA
# 5427  51.012286   2.040472         2.800186  BBAS3.SA
# 5447  50.585214   2.058891         2.508619  BBAS3.SA
# 5466  50.093450   1.745587         2.337280  BBAS3.SA
#
# [85 rows x 8 columns]
# [*********************100%***********************]  1 of 1 completed
# <class 'pandas.core.series.Series'>
# Dataframe
#              Date   AnoMes  Var Percentual  DiferencaDesvios  \
# 0     2002-01-01  2002-01             NaN               NaN
# 1     2002-01-02  2002-01        0.000000               NaN
# 2     2002-01-03  2002-01        0.761416               NaN
# 3     2002-01-04  2002-01       -0.377693               NaN
# 4     2002-01-07  2002-01        0.379125               NaN
# ...          ...      ...             ...               ...
# 5500  2023-12-21  2023-12       -0.064648          4.001698
# 5501  2023-12-22  2023-12        0.248550          3.967770
# 5502  2023-12-26  2023-12        0.398674          3.930979
# 5503  2023-12-27  2023-12        0.727993          3.931860
# 5504  2023-12-28  2023-12        0.394215          3.938358
#
#       MediaDiferencaDesvios        rsi  Variancia  Media Variancia     Stock
# 0                       NaN        NaN        NaN              NaN  BBDC3.SA
# 1                       NaN        NaN        NaN              NaN  BBDC3.SA
# 2                       NaN        NaN        NaN              NaN  BBDC3.SA
# 3                       NaN        NaN        NaN              NaN  BBDC3.SA
# 4                       NaN        NaN        NaN              NaN  BBDC3.SA
# ...                     ...        ...        ...              ...       ...
# 5500               5.408381  73.720135   1.983234         1.934969  BBDC3.SA
# 5501               5.394140  74.231779   1.979746         1.933695  BBDC3.SA
# 5502               5.379812  75.072199   1.979275         1.932952  BBDC3.SA
# 5503               5.365481  76.580251   1.983326         1.932301  BBDC3.SA
# 5504               5.351055  77.383944   1.972328         1.932215  BBDC3.SA
#
# [5505 rows x 9 columns]
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
#           ...
# 5500    5.405458
# 5501    5.394244
# 5502    5.383022
# 5503    5.371818
# 5504    5.360517
# Name: Var Percentual, Length: 5505, dtype: float64
# Dados únicos
#             Date  Var Percentual  DiferencaDesvios  MediaDiferencaDesvios  \
# 365   2003-05-27        2.103889          5.953795               7.874263
# 374   2003-06-09       -1.602191          5.802403               7.893180
# 406   2003-07-23        1.310034          5.524023               7.769671
# 417   2003-08-07        3.560893          5.248874               7.624174
# 440   2003-09-09       -4.498580          5.193738               7.281129
# ...          ...             ...               ...                    ...
# 5203  2022-10-13       -1.325302          4.334236               5.222478
# 5321  2023-04-04        1.532918          5.591040               5.618505
# 5338  2023-05-02       -2.576472          5.556483               5.647673
# 5388  2023-07-12       -0.625865          4.378065               5.700805
# 5451  2023-10-10        0.791143          4.057642               5.741564
#
#             rsi  Variancia  Media Variancia     Stock
# 365   48.317172   3.938630         5.997552  BBDC3.SA
# 374   48.890955   3.740875         5.703261  BBDC3.SA
# 406   50.741495   3.390537         4.591131  BBDC3.SA
# 417   49.777739   3.061186         4.252434  BBDC3.SA
# 440   50.451440   2.997212         3.641778  BBDC3.SA
# ...         ...        ...              ...       ...
# 5203  48.577966   2.087289         2.124496  BBDC3.SA
# 5321  50.104083   3.473303         5.845641  BBDC3.SA
# 5338  50.899673   3.430500         5.547561  BBDC3.SA
# 5388  50.773667   2.129717         4.106959  BBDC3.SA
# 5451  48.049206   1.829385         2.299144  BBDC3.SA
#
# [92 rows x 8 columns]
#            Date  Var Percentual  DiferencaDesvios  MediaDiferencaDesvios  \
# 0    2003-07-02        1.681636          5.194070               7.197635
# 1    2003-08-05        2.238791          4.748832               7.061025
# 2    2003-09-24        0.921791          4.847585               6.693434
# 3    2003-10-27        0.550761          4.814651               6.331659
# 4    2003-11-10       -1.041335          4.683264               6.175630
# ..          ...             ...               ...                    ...
# 440  2022-10-13       -1.325302          4.334236               5.222478
# 441  2023-04-04        1.532918          5.591040               5.618505
# 442  2023-05-02       -2.576472          5.556483               5.647673
# 443  2023-07-12       -0.625865          4.378065               5.700805
# 444  2023-10-10        0.791143          4.057642               5.741564
#
#            rsi  Variancia  Media Variancia     Stock
# 0    49.926729   2.997596         4.409467  PETR4.SA
# 1    48.910153   2.505711         3.726799  PETR4.SA
# 2    50.194495   2.611008         3.081253  PETR4.SA
# 3    49.589733   2.575652         2.722941  PETR4.SA
# 4    51.910799   2.436995         2.646351  PETR4.SA
# ..         ...        ...              ...       ...
# 440  48.577966   2.087289         2.124496  BBDC3.SA
# 441  50.104083   3.473303         5.845641  BBDC3.SA
# 442  50.899673   3.430500         5.547561  BBDC3.SA
# 443  50.773667   2.129717         4.106959  BBDC3.SA
# 444  48.049206   1.829385         2.299144  BBDC3.SA
#
# [445 rows x 8 columns]
